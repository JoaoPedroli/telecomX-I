# %% [markdown]
# <a href="https://colab.research.google.com/github/JoaoPedroli/telecomX-challenge-II-ONE/blob/main/TelecomX_BR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracão

# %%
import pandas as pd
import requests
import json

response = requests.get('https://raw.githubusercontent.com/alura-cursos/challenge2-data-science/main/TelecomX_Data.json')
data = json.loads(response.text)

df = pd.json_normalize(data, sep='_')

df.head()
# Out:
#    customerID Churn customer_gender  customer_SeniorCitizen customer_Partner  \
# 0  0002-ORFBO    No          Female                       0              Yes
# 1  0003-MKNFE    No            Male                       0               No
# 2  0004-TLHLJ   Yes            Male                       0               No
# 3  0011-IGKFF   Yes            Male                       1              Yes
# 4  0013-EXCHZ   Yes          Female                       1              Yes
#
#   customer_Dependents  customer_tenure phone_PhoneService phone_MultipleLines  \
# 0                 Yes                9                Yes                  No
# 1                  No                9                Yes                 Yes
# 2                  No                4                Yes                  No
# 3                  No               13                Yes                  No
# 4                  No                3                Yes                  No
#
# ...

# %%
df['Churn'] = df['Churn'].apply(lambda x: 1 if x == 'Yes' else 0)
df['customer_Partner'] = df['customer_Partner'].apply(lambda x: 1 if x == 'Yes' else 0)
df['customer_Dependents'] = df['customer_Dependents'].apply(lambda x: 1 if x == 'Yes' else 0)
df['phone_PhoneService'] = df['phone_PhoneService'].apply(lambda x: 1 if x == 'Yes' else 0)
df['phone_MultipleLines'] = df['phone_MultipleLines'].apply(lambda x: 1 if x == 'Yes' else 0)
df['internet_DeviceProtection'] = df['internet_DeviceProtection'].apply(lambda x: 1 if x == 'Yes' else 0)
df['internet_TechSupport'] = df['internet_TechSupport'].apply(lambda x: 1 if x == 'Yes' else 0)
df['internet_StreamingTV'] = df['internet_StreamingTV'].apply(lambda x: 1 if x == 'Yes' else 0)
df['internet_StreamingMovies'] = df['internet_StreamingMovies'].apply(lambda x: 1 if x == 'Yes' else 0)
df['account_PaperlessBilling'] = df['account_PaperlessBilling'].apply(lambda x: 1 if x == 'Yes' else 0)
df.head()
# Out:
#    customerID  Churn customer_gender  customer_SeniorCitizen  \
# 0  0002-ORFBO      0          Female                       0
# 1  0003-MKNFE      0            Male                       0
# 2  0004-TLHLJ      1            Male                       0
# 3  0011-IGKFF      1            Male                       1
# 4  0013-EXCHZ      1          Female                       1
#
#    customer_Partner  customer_Dependents  customer_tenure  phone_PhoneService  \
# 0                 1                    1                9                   1
# 1                 0                    0                9                   1
# 2                 0                    0                4                   1
# 3                 1                    0               13                   1
# 4                 1                    0                3                   1
#
#    phone_MultipleLines internet_InternetService  ... internet_OnlineBackup  \
# ...

# %% [markdown]
# #🔧 Transformação

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   int64
#  2   customer_gender            7267 non-null   object
#  3   customer_SeniorCitizen     7267 non-null   int64
#  4   customer_Partner           7267 non-null   int64
#  5   customer_Dependents        7267 non-null   int64
#  6   customer_tenure            7267 non-null   int64
#  7   phone_PhoneService         7267 non-null   int64
#  8   phone_MultipleLines        7267 non-null   int64
#  9   internet_InternetService   7267 non-null   object
#  10  internet_OnlineSecurity    7267 non-null   object
#  11  internet_OnlineBackup      7267 non-null   object
#  12  internet_DeviceProtection  7267 non-null   int64
# ...

# %%
df['account_Charges_Total'] = pd.to_numeric(df['account_Charges_Total'], errors='coerce')
print("Number of values converted to NaN in 'account_Charges_Total': ", df['account_Charges_Total'].isnull().sum())
# Out:
# Number of values converted to NaN in 'account_Charges_Total':  11

# %%
df['Contas_Diarias'] = (df['account_Charges_Monthly'] / 30).round(2)
df.head()
# Out:
#    customerID  Churn customer_gender  customer_SeniorCitizen  \
# 0  0002-ORFBO      0          Female                       0
# 1  0003-MKNFE      0            Male                       0
# 2  0004-TLHLJ      1            Male                       0
# 3  0011-IGKFF      1            Male                       1
# 4  0013-EXCHZ      1          Female                       1
#
#    customer_Partner  customer_Dependents  customer_tenure  phone_PhoneService  \
# 0                 1                    1                9                   1
# 1                 0                    0                9                   1
# 2                 0                    0                4                   1
# 3                 1                    0               13                   1
# 4                 1                    0                3                   1
#
#    phone_MultipleLines internet_InternetService  ...  \
# 0                    0                      DSL  ...
# ...

# %% [markdown]
# #📊 Carga e análise

# %%
print(f"Média de churns: {df['Churn'].mean() * 100:.2f}%")
print(f"Média de gastos p/ pessoa no mes: {df['account_Charges_Monthly'].mean():.2f}")
print(f"Mediana de gastos p/ pessoa no mes: {df['account_Charges_Monthly'].median():.2f}")
print(f"Desvio Padrão de gastos p/ pessoa no mes: {df['account_Charges_Monthly'].std():.2f}")
# Out:
# Média de churns: 25.72%
# Média de gastos p/ pessoa no mes: 64.72
# Mediana de gastos p/ pessoa no mes: 70.30
# Desvio Padrão de gastos p/ pessoa no mes: 30.13

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 5))
plt.pie(df['Churn'].value_counts(), labels=['Nº de clientes que saíram', 'Nº de clientes que permaneceram'], autopct='%1.1f%%', colors=['#ff4a1c', '#b2ffa9'])
plt.title('Distribuição de Churn')
plt.show()

# %%
categorical_cols = ['customer_gender', 'account_Contract', 'account_PaymentMethod', 'customer_Partner', 'customer_Dependents']

for col in categorical_cols:
    plt.figure(figsize=(7, 4))
    sns.countplot(data=df, x=col, hue='Churn', palette=['#ff4a1c', '#b2ffa9'])
    plt.ylabel('Quantidade')
    plt.title(f'Distribuição de saídas por {col}')
    plt.legend(title='Churn', loc='upper right', labels=['Saiu', 'Não Saiu'])
    if col == 'customer_Partner':
        plt.xticks(ticks=[0, 1], labels=['Tem Esposa', 'Não tem esposa'])
    elif col == 'customer_Dependents':
        plt.xticks(ticks=[0, 1], labels=['Tem dependentes', 'Não tem dependentes'])
    elif col == 'account_PaymentMethod':
        plt.xticks(rotation=15)
    plt.show()
    print()

# %% [markdown]
# #📄Relatorio Final

# %% [markdown]
# * Introdução: Esta análise foi criada com o objetivo de analisar o porquê da empresa estar tendo uma evasão tão considerável de clientes, em um espaço tão curto de tempo, que denominamos como ***Churn* de clientes**.
# * Limpeza e Tratamento de Dados: Foram realizadas alguns tratamentos de dados de modo que eles ficassem mais paupáveis para visualizações futuras. Começando pelo tratamento dos dados categóricos com "Yes" ou "No", que foram alterados para binários (0 ou 1), com o objetivo de tornar os dados dessas colunas mais rápidos de serem computados e tratados futuramente. Também foi realizado um tratamento para que não tivessem dados nulos na tabela. Além da criação de uma nova tabela "Contas Diárias".
# * Análise Exploratória de Dados: Começamos extraindo algumas informações como a média de churns atualmente, e algumas informações sobre gastos. Após isso, verificamos a porcentagem de número de clientes que saíram (churns), que é de aproximadamente 74%. Após isso foi verificado alguns pontos consideráveis em gráficos categóricos.
# * Conclusões e Insights: Fica perceptível que a evasão em planos mensais é extremamente mais baixa, pois os clientes provavelmente tem mais garantia de que mesmo que a entrega não seja de qualidade, ainda terá tempo de fazer mudanças rápidas. Algo a se notar também, é que o número de churns de clientes que utilizam o método de pagamento "Cheque eletrônico" é consideravelmente menor em comparação ao número de clientes que ficaram, na mesma categoria. Fora isso, também nota-se uma proporção maior de clientes com família, que escolheram ficar.
# * Recomendações: Recomenda-se, portanto, migrar os esforços para descobrir por que os outros métodos de pagamento estão tendo tão pouca retenção de clientes, e também aumtentar, talvez, o foco no público com família, pois pelo visto estes terão maior probabilidade de retenção.
